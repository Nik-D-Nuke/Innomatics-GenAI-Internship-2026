# %% [markdown]
# ## ASSIGNMENT 7 (OOPS)

# %% [markdown]
# #### Problem 1: Smart Light Controller
# Problem Statement
#
# Create a class to control a smart light that can be turned ON or OFF and display its status.
#
# 🌍 Real-Time Use:
# Smart home automation systems

# %%
class smart_light:
    def __init__(self,name):
        self.name=name
        self.status='OFF'
        
    def turn_on(self):
        self.status='ON'

    def turn_off(self):
        self.status='OFF'
        
    def display_status(self):
        print(f"{self.name} is {self.status}")

bed_light = smart_light("Bedroom Light")
bed_light.turn_on()
bed_light.display_status()
# Out:
# Bedroom Light is ON

# %% [markdown]
# #### Problem 2: Employee ID Card System
#  Problem Statement
#
# Create a class that stores employee name, ID, and department and displays ID card details.
#
# Real-Time Use
# Corporate HR systems

# %%
class employee:
    def __init__(self,name,id,dept):
        self.name=name
        self.id=id
        self.dept=dept
        
    def display(self):
        print('Employee ID Card')
        print(f'Name: {self.name}')
        print(f'ID: {self.id}')
        print(f'Department: {self.dept}')
        
e1=employee('Rahul','EMP102','IT')
e1.display()
# Out:
# Employee ID Card
# Name: Rahul
# ID: EMP102
# Department: IT

# %% [markdown]
# #### Problem 3: Mobile Contact Record
# Problem Statement
#
# Create a class to store contact name and phone number and display contact information.
#
# Real-Time Use
# Mobile contact applications

# %%
class mobile_info:
    def __init__(self,name,phno):
        self.name=name
        self.phno=phno
    
    def display(self):
        print(f'Contact Saved')
        print(f'Name: {self.name}')
        print(f'Phone: {self.phno}')
        
m1=mobile_info('Anita',9876543210)
m1.display()
# Out:
# Contact Saved
# Name: Anita
# Phone: 9876543210

# %% [markdown]
# #### Problem 4: Product Price Tag Generator
#
# Problem Statement
#
# Create a class that stores product name and price and prints a formatted price tag.
#
#  Real-Time Use
# Retail billing systems

# %%
class product:
    def __init__(self,name,price):
        self.name=name
        self.price=price
        
    def price_tag(self):
        print(f'Product:{self.name}')
        print(f'Price:₹{self.price}') #or print(f'Price:\u20B9{self.price}')
        
name = input("Product Name: ")
price = int(input("Price: "))

p1 = product(name, price)
p1.price_tag()
# Out:
# Product:Headphones
# Price:₹2499

# %% [markdown]
# #### Problem 5: Movie Rating Display System
#
# Problem Statement
#
# Create a class that stores movie name and rating and displays movie details.
#
# Real-Time Use
# Streaming platforms

# %%
class movie_rating:
    def __init__(self,movie_name,rating):
        self.name=movie_name
        self.rating=rating
        
    def display_details(self):
        print(f'Movie:{self.name}')
        print(f'Rating:{round(self.rating,1)}/5')
    
movie=input('Movie Name:')
rating=float(input('Ratings(between 1 to 5):'))

m1=movie_rating(movie,rating)
m1.display_details()
# Out:
# Movie:Inception
# Rating:4.8/5

# %% [markdown]
# #### Problem 6: Delivery Address Manager
#
# Problem Statement
#
# Create a class that stores customer name and delivery address and prints delivery details.
#
# Real-Time Use
# Courier and logistics platforms

# %%
class DeliveryAddress:
    def __init__(self, customer_name, address):
        self.customer_name = customer_name
        self.address = address

    def display_details(self):
        print("Delivery Details")
        print(f"Customer: {self.customer_name}")
        print(f"Address: {self.address}")

customer = input("Customer Name: ")
address = input("Address: ")
d1 = DeliveryAddress(customer, address)
d1.display_details()
# Out:
# Delivery Details
# Customer: Suman
# Address: Hyderabad
